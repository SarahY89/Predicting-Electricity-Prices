# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahY89/Predicting-Electricity-Prices/blob/main/Predicting_Electricity_prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Predicting Electricity Prices**
#
# Predict the daily price variation of electricity futures contracts in England and Scotland.

# %% [markdown]
# # loading Libraries

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings(action='ignore')

# Preprocessing Libraries
from sklearn.preprocessing import RobustScaler

# Model training libraries
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
from collections import Counter
from imblearn.under_sampling import NearMiss               # Undersampling
from imblearn.over_sampling import RandomOverSampler       # Oversampling
from imblearn.combine import SMOTETomek                    # Both Undersampling & Oversampling
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# For checking acuracy
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %% [markdown]
# # Data Exploration and Data Cleaning

# %%
test_data = pd.read_csv('/content/test.csv')
train_data =pd.read_csv('/content/train.csv')
# preview of data

test_data.head(5)
# Out:
#      ID  DAY_ID COUNTRY  EN_CONSUMPTION  SC_CONSUMPTION  EN_SC_EXCHANGE  \
# 0  1905     922      FR        0.850673        1.754694        2.119081
# 1  1560     640      FR       -0.163169       -1.000510       -0.844216
# 2   978     749      FR        1.095720        0.708132        0.972202
# 3   430      70      DE        0.962114        0.978202       -0.488579
# 4  1277     612      FR        0.084725       -0.529281       -0.703383
#
#    EN_SC_EXCHANGE.1  EN_NET_EXPORT  SC_NET_EXPORT  EN_NET_IMPORT  ...  \
# 0         -2.119081      -0.152048      -2.652947       0.152048  ...
# 1          0.844216      -1.248088      -0.483415       1.248088  ...
# 2         -0.972202            NaN            NaN            NaN  ...
# 3          0.488579      -0.009066       0.350190       0.009066  ...
# 4          0.703383      -0.867186       0.701708       0.867186  ...
#
#    SC_RESIDUAL_LOAD   EN_RAIN   SC_RAIN   EN_WIND   SC_WIND   EN_TEMP  \
# 0          1.657977 -0.611095 -1.545250  0.599079  1.081256 -0.674632
# 1         -0.916060  0.028255 -0.704780 -0.715431 -0.720297  0.366905
# 2          0.846909  0.870326 -0.094561 -0.266383 -0.936848 -1.188318
# 3          0.722904 -0.737855 -0.451625 -0.870904 -0.652968  0.877630
# 4         -0.524358 -0.410014 -0.656610 -0.412824 -0.341855 -1.674868
#
#     SC_TEMP   GAS_RET  COAL_RET  CARBON_RET
# 0 -1.623146  0.325328  2.461414    1.121652
# 1  0.281706  0.107630  0.326670    0.726900
# 2 -0.171556 -0.790452 -0.070311   -0.493792
# 3  0.114314 -1.091242 -0.420936   -1.187919
# 4 -0.149335  1.015038  0.697738    1.847625
#
# [5 rows x 35 columns]
# Warning: Total number of columns (35) exceeds max_columns (20) limiting to first (20) columns.
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_36, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_37, *['ID'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_38, *['DAY_ID'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_39, *['EN_CONSUMPTION'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_40, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_41, *['ID'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_42, *['DAY_ID'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_43, *['EN_CONSUMPTION'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_44, *['COUNTRY'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_45, *[[['index', 'ID'], ['ID', 'DAY_ID'], ['DAY_ID', 'EN_CONSUMPTION'], ['EN_CONSUMPTION', 'SC_CONSUMPTION']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_46, *['index', 'COUNTRY'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_47, *['ID', 'COUNTRY'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_48, *['DAY_ID', 'COUNTRY'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_49, *['EN_CONSUMPTION', 'COUNTRY'], **{'inner': 'stick'})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_50, *['index', 'ID', 'COUNTRY'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_51, *['index', 'DAY_ID', 'COUNTRY'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_52, *['index', 'EN_CONSUMPTION', 'COUNTRY'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_53, *['index', 'SC_CONSUMPTION', 'COUNTRY'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_54, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_55, *['ID'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_56, *['DAY_ID'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_57, *['EN_CONSUMPTION'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_58, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_59, *['ID'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_60, *['DAY_ID'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_61, *['EN_CONSUMPTION'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_62, *['COUNTRY'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_63, *[[['index', 'ID'], ['ID', 'DAY_ID'], ['DAY_ID', 'EN_CONSUMPTION'], ['EN_CONSUMPTION', 'SC_CONSUMPTION']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_64, *['index', 'COUNTRY'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_65, *['ID', 'COUNTRY'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_66, *['DAY_ID', 'COUNTRY'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_67, *['EN_CONSUMPTION', 'COUNTRY'], **{'inner': 'stick'})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_68, *['index', 'ID', 'COUNTRY'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_69, *['index', 'DAY_ID', 'COUNTRY'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_70, *['index', 'EN_CONSUMPTION', 'COUNTRY'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_71, *['index', 'SC_CONSUMPTION', 'COUNTRY'], **{})
# chart

# %%
train_data.head(5)
# Out:
#      ID  DAY_ID COUNTRY  EN_CONSUMPTION  SC_CONSUMPTION  EN_SC_EXCHANGE  \
# 0  1675     809      FR        1.529204        1.106682       -1.855327
# 1   136     292      DE        0.359496       -0.219398        0.001369
# 2   522     188      DE        0.556084       -0.264298        1.083886
# 3  1292    1027      FR       -0.093290       -0.874992       -2.233178
# 4    37    1058      DE        0.406000       -0.634804       -1.513080
#
#    EN_SC_EXCHANGE.1  EN_NET_EXPORT  SC_NET_EXPORT  EN_NET_IMPORT  ...  \
# 0          1.855327      -0.218658       1.450426       0.218658  ...
# 1         -0.001369       0.474434      -0.029744      -0.474434  ...
# 2         -1.083886       0.462565      -0.231322      -0.462565  ...
# 3          2.233178      -1.585888       1.151177       1.585888  ...
# 4          1.513080      -1.173137       1.316583       1.173137  ...
#
#     EN_RAIN   SC_RAIN   EN_WIND   SC_WIND   EN_TEMP   SC_TEMP   GAS_RET  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN  0.876984
# 1 -0.126422  1.852433 -0.859444 -0.879027  0.678797 -0.081514 -0.087966
# 2  1.090211  0.916461  1.696387  0.581391 -0.392780 -0.588684  0.793277
# 3  0.495799 -0.529800 -0.716488 -0.969511  0.770310 -0.101407 -0.351418
# 4  0.392121 -1.648699 -0.653331 -0.432017  1.208224  0.776142  0.807354
#
#    COAL_RET  CARBON_RET    TARGET
# 0  0.819520    1.320373  0.077687
# 1  0.078601   -0.375356  1.007261
# 2  0.216866    0.932713 -0.152640
# 3  0.196313   -0.404838 -2.788408
# 4  1.170828    2.566665  0.084096
#
# [5 rows x 36 columns]
# Warning: Total number of columns (36) exceeds max_columns (20) limiting to first (20) columns.
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_72, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_73, *['ID'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_74, *['DAY_ID'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_75, *['EN_CONSUMPTION'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_76, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_77, *['ID'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_78, *['DAY_ID'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_79, *['EN_CONSUMPTION'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(_df_80, *['COUNTRY'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_81, *[[['index', 'ID'], ['ID', 'DAY_ID'], ['DAY_ID', 'EN_CONSUMPTION'], ['EN_CONSUMPTION', 'SC_CONSUMPTION']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_82, *['index', 'COUNTRY'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_83, *['ID', 'COUNTRY'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_84, *['DAY_ID', 'COUNTRY'], **{'inner': 'stick'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(_df_85, *['EN_CONSUMPTION', 'COUNTRY'], **{'inner': 'stick'})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_86, *['index', 'ID', 'COUNTRY'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_87, *['index', 'DAY_ID', 'COUNTRY'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_88, *['index', 'EN_CONSUMPTION', 'COUNTRY'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_89, *['index', 'SC_CONSUMPTION', 'COUNTRY'], **{})
# chart

# %%
test_data.describe()
# Out:
#                 ID       DAY_ID  EN_CONSUMPTION  SC_CONSUMPTION  \
# count   400.000000   400.000000      400.000000      400.000000
# mean   1089.157500   601.757500        0.422966        0.005579
# std     617.077243   348.832415        0.706657        0.961821
# min       2.000000     1.000000       -2.265563       -1.462350
# 25%     580.750000   294.500000       -0.043326       -0.707637
# 50%    1085.500000   605.500000        0.348298       -0.403379
# 75%    1630.250000   901.250000        0.958659        0.687231
# max    2146.000000  1213.000000        2.033851        2.632105
#
#        EN_SC_EXCHANGE  EN_SC_EXCHANGE.1  EN_NET_EXPORT  SC_NET_EXPORT  \
# count      394.000000        394.000000     367.000000     383.000000
# mean        -0.117583          0.117583      -0.234939      -0.146567
# std          0.963578          0.963578       0.964935       1.072252
# min         -2.212659         -2.634831      -2.464849      -2.825331
# 25%         -0.845439         -0.576607      -0.940761      -0.883043
# 50%         -0.164624          0.164624      -0.299681      -0.016927
# 75%          0.576607          0.845439       0.465162       0.702661
# max          2.634831          2.212659       1.902134       1.874276
#
#        EN_NET_IMPORT  SC_NET_IMPORT  ...  SC_RESIDUAL_LOAD     EN_RAIN  \
# count     367.000000     383.000000  ...        400.000000  373.000000
# mean        0.234939       0.146567  ...         -0.116122   -0.118741
# std         0.964935       1.072252  ...          0.951285    0.917557
# min        -1.902134      -1.874276  ...         -1.552772   -2.128531
# 25%        -0.465162      -0.702661  ...         -0.806116   -0.676720
# 50%         0.299681       0.016927  ...         -0.458687   -0.303346
# 75%         0.940761       0.883043  ...          0.487575    0.308184
# max         2.464849       2.825331  ...          2.537454    4.216460
#
#           SC_RAIN     EN_WIND     SC_WIND     EN_TEMP     SC_TEMP     GAS_RET  \
# count  373.000000  373.000000  373.000000  373.000000  373.000000  400.000000
# mean     0.086518    0.123157    0.130545   -0.029404    0.007376   -0.030924
# std      1.224134    1.078073    1.065294    0.929477    0.952264    1.121532
# min     -1.545250   -1.319222   -1.531520   -3.494385   -3.238233   -4.269256
# 25%     -0.485651   -0.681080   -0.698770   -0.577735   -0.664664   -0.790531
# 50%     -0.212982   -0.261571   -0.261132   -0.105398   -0.063596   -0.011623
# 75%      0.172090    0.624706    0.827451    0.546385    0.785115    0.701231
# max      9.473201    5.085624    3.499060    2.771601    2.439156    3.840718
#
#          COAL_RET  CARBON_RET
# count  400.000000  400.000000
# mean     0.091778    0.114773
# std      1.022850    1.167679
# min     -5.392852   -4.281790
# 25%     -0.454466   -0.536534
# 50%      0.045626    0.098322
# 75%      0.697656    0.647153
# max      3.746576    5.471818
#
# [8 rows x 34 columns]
# Warning: Total number of columns (34) exceeds max_columns (20) limiting to first (20) columns.

# %%
train_data.describe()
# Out:
#                 ID       DAY_ID  EN_CONSUMPTION  SC_CONSUMPTION  \
# count  1094.000000  1094.000000     1094.000000     1094.000000
# mean   1066.763254   588.243144        0.429078       -0.029396
# std     618.528352   343.766745        0.661165        0.903102
# min       0.000000     0.000000       -2.077774       -1.456829
# 25%     531.500000   292.250000       -0.027346       -0.724195
# 50%    1075.500000   585.500000        0.358261       -0.390642
# 75%    1587.500000   881.000000        0.918392        0.614371
# max    2145.000000  1215.000000        2.033851        3.300640
#
#        EN_SC_EXCHANGE  EN_SC_EXCHANGE.1  EN_NET_EXPORT  SC_NET_EXPORT  \
# count     1075.000000       1075.000000    1003.000000    1041.000000
# mean        -0.155742          0.155742      -0.264159      -0.045446
# std          0.972897          0.972897       0.955051       1.076380
# min         -2.856874         -2.634831      -2.464849      -2.825331
# 25%         -0.904623         -0.647758      -0.997321      -0.843185
# 50%         -0.156136          0.156136      -0.329230       0.156117
# 75%          0.647758          0.904623       0.449166       0.834720
# max          2.634831          2.856874       2.279619       1.951516
#
#        EN_NET_IMPORT  SC_NET_IMPORT  ...      EN_RAIN      SC_RAIN  \
# count    1003.000000    1041.000000  ...  1027.000000  1027.000000
# mean        0.264159       0.045446  ...    -0.008445    -0.005035
# std         0.955051       1.076380  ...     1.006175     0.981255
# min        -2.279619      -1.951516  ...    -2.128531    -1.726420
# 25%        -0.449166      -0.834720  ...    -0.629062    -0.527772
# 50%         0.329230      -0.156117  ...    -0.260395    -0.231347
# 75%         0.997321       0.843185  ...     0.361552     0.153973
# max         2.464849       2.825331  ...     7.756118     7.217889
#
#            EN_WIND      SC_WIND      EN_TEMP      SC_TEMP      GAS_RET  \
# count  1027.000000  1027.000000  1027.000000  1027.000000  1094.000000
# mean      0.104513     0.120395     0.023563     0.008778     0.090685
# std       1.048691     1.051324     0.987581     1.021730     1.087650
# min      -1.880419    -1.895319    -4.549638    -5.787097    -5.349463
# 25%      -0.640639    -0.660441    -0.634046    -0.645716    -0.541564
# 50%      -0.261571    -0.223610     0.006600    -0.013710     0.034933
# 75%       0.638035     0.768803     0.673510     0.676436     0.657406
# max       5.085624     4.965028     2.858758     2.817239     5.674778
#
#           COAL_RET   CARBON_RET       TARGET
# count  1094.000000  1094.000000  1094.000000
# mean      0.050736     0.067983     0.050955
# std       1.038094     1.072550     0.962189
# min      -5.706442    -4.281790    -6.519268
# 25%      -0.458038    -0.517698    -0.211150
# 50%       0.066273     0.033874    -0.002955
# 75%       0.630335     0.591783     0.235224
# max       3.683777     5.471818     7.786578
#
# [8 rows x 35 columns]
# Warning: Total number of columns (35) exceeds max_columns (20) limiting to first (20) columns.

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 35 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                400 non-null    int64
#  1   DAY_ID            400 non-null    int64
#  2   COUNTRY           400 non-null    object
#  3   EN_CONSUMPTION    400 non-null    float64
#  4   SC_CONSUMPTION    400 non-null    float64
#  5   EN_SC_EXCHANGE    394 non-null    float64
#  6   EN_SC_EXCHANGE.1  394 non-null    float64
#  7   EN_NET_EXPORT     367 non-null    float64
#  8   SC_NET_EXPORT     383 non-null    float64
#  9   EN_NET_IMPORT     367 non-null    float64
#  10  SC_NET_IMPORT     383 non-null    float64
#  11  EN_GAS            400 non-null    float64
#  12  SC_GAS            400 non-null    float64
#  13  EN_COAL           400 non-null    float64
#  14  SC_COAL           400 non-null    float64
#  15  EN_HYDRO          400 non-null    float64
#  16  SC_HYDRO          400 non-null    float64
#  17  EN_NUCLEAR        400 non-null    float64
#  18  SC_NUCLEAR        400 non-null    float64
#  19  EN_SOLAR          400 non-null    float64
#  20  SC_SOLAR          400 non-null    float64
#  21  EN_WINDPOW        400 non-null    float64
#  22  SC_WINDPOW        400 non-null    float64
#  23  EN_LIGNITE        400 non-null    float64
#  24  EN_RESIDUAL_LOAD  400 non-null    float64
#  25  SC_RESIDUAL_LOAD  400 non-null    float64
#  26  EN_RAIN           373 non-null    float64
#  27  SC_RAIN           373 non-null    float64
#  28  EN_WIND           373 non-null    float64
#  29  SC_WIND           373 non-null    float64
#  30  EN_TEMP           373 non-null    float64
#  31  SC_TEMP           373 non-null    float64
#  32  GAS_RET           400 non-null    float64
#  33  COAL_RET          400 non-null    float64
#  34  CARBON_RET        400 non-null    float64
# dtypes: float64(32), int64(2), object(1)
# memory usage: 109.5+ KB

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1094 entries, 0 to 1093
# Data columns (total 36 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1094 non-null   int64
#  1   DAY_ID            1094 non-null   int64
#  2   COUNTRY           1094 non-null   object
#  3   EN_CONSUMPTION    1094 non-null   float64
#  4   SC_CONSUMPTION    1094 non-null   float64
#  5   EN_SC_EXCHANGE    1075 non-null   float64
#  6   EN_SC_EXCHANGE.1  1075 non-null   float64
#  7   EN_NET_EXPORT     1003 non-null   float64
#  8   SC_NET_EXPORT     1041 non-null   float64
#  9   EN_NET_IMPORT     1003 non-null   float64
#  10  SC_NET_IMPORT     1041 non-null   float64
#  11  EN_GAS            1094 non-null   float64
#  12  SC_GAS            1094 non-null   float64
#  13  EN_COAL           1094 non-null   float64
#  14  SC_COAL           1094 non-null   float64
#  15  EN_HYDRO          1094 non-null   float64
#  16  SC_HYDRO          1094 non-null   float64
#  17  EN_NUCLEAR        1094 non-null   float64
#  18  SC_NUCLEAR        1094 non-null   float64
#  19  EN_SOLAR          1094 non-null   float64
#  20  SC_SOLAR          1094 non-null   float64
#  21  EN_WINDPOW        1094 non-null   float64
#  22  SC_WINDPOW        1094 non-null   float64
#  23  EN_LIGNITE        1094 non-null   float64
#  24  EN_RESIDUAL_LOAD  1094 non-null   float64
#  25  SC_RESIDUAL_LOAD  1094 non-null   float64
#  26  EN_RAIN           1027 non-null   float64
#  27  SC_RAIN           1027 non-null   float64
#  28  EN_WIND           1027 non-null   float64
#  29  SC_WIND           1027 non-null   float64
#  30  EN_TEMP           1027 non-null   float64
#  31  SC_TEMP           1027 non-null   float64
#  32  GAS_RET           1094 non-null   float64
#  33  COAL_RET          1094 non-null   float64
#  34  CARBON_RET        1094 non-null   float64
#  35  TARGET            1094 non-null   float64
# dtypes: float64(33), int64(2), object(1)
# memory usage: 307.8+ KB

# %%
# Null % check amongst columns
round((test_data.isnull().sum()/len(test_data)*100),2)
# Out:
# ID                  0.00
# DAY_ID              0.00
# COUNTRY             0.00
# EN_CONSUMPTION      0.00
# SC_CONSUMPTION      0.00
# EN_SC_EXCHANGE      1.50
# EN_SC_EXCHANGE.1    1.50
# EN_NET_EXPORT       8.25
# SC_NET_EXPORT       4.25
# EN_NET_IMPORT       8.25
# SC_NET_IMPORT       4.25
# EN_GAS              0.00
# SC_GAS              0.00
# EN_COAL             0.00
# SC_COAL             0.00
# EN_HYDRO            0.00
# SC_HYDRO            0.00
# EN_NUCLEAR          0.00
# SC_NUCLEAR          0.00
# EN_SOLAR            0.00
# SC_SOLAR            0.00
# EN_WINDPOW          0.00
# SC_WINDPOW          0.00
# EN_LIGNITE          0.00
# EN_RESIDUAL_LOAD    0.00
# SC_RESIDUAL_LOAD    0.00
# EN_RAIN             6.75
# SC_RAIN             6.75
# EN_WIND             6.75
# SC_WIND             6.75
# EN_TEMP             6.75
# SC_TEMP             6.75
# GAS_RET             0.00
# COAL_RET            0.00
# CARBON_RET          0.00
# dtype: float64

# %%
# Null % check amongst columns
round((train_data.isnull().sum()/len(train_data)*100),2)
# Out:
# ID                  0.00
# DAY_ID              0.00
# COUNTRY             0.00
# EN_CONSUMPTION      0.00
# SC_CONSUMPTION      0.00
# EN_SC_EXCHANGE      1.74
# EN_SC_EXCHANGE.1    1.74
# EN_NET_EXPORT       8.32
# SC_NET_EXPORT       4.84
# EN_NET_IMPORT       8.32
# SC_NET_IMPORT       4.84
# EN_GAS              0.00
# SC_GAS              0.00
# EN_COAL             0.00
# SC_COAL             0.00
# EN_HYDRO            0.00
# SC_HYDRO            0.00
# EN_NUCLEAR          0.00
# SC_NUCLEAR          0.00
# EN_SOLAR            0.00
# SC_SOLAR            0.00
# EN_WINDPOW          0.00
# SC_WINDPOW          0.00
# EN_LIGNITE          0.00
# EN_RESIDUAL_LOAD    0.00
# SC_RESIDUAL_LOAD    0.00
# EN_RAIN             6.12
# SC_RAIN             6.12
# EN_WIND             6.12
# SC_WIND             6.12
# EN_TEMP             6.12
# SC_TEMP             6.12
# GAS_RET             0.00
# COAL_RET            0.00
# CARBON_RET          0.00
# TARGET              0.00
# dtype: float64

# %%
# DF.corr to show correlation of values
test_data.corr()
# Out:
#                         ID    DAY_ID  EN_CONSUMPTION  SC_CONSUMPTION  \
# ID                1.000000  0.009115        0.054793       -0.026036
# DAY_ID            0.009115  1.000000        0.031010        0.033269
# EN_CONSUMPTION    0.054793  0.031010        1.000000        0.778765
# SC_CONSUMPTION   -0.026036  0.033269        0.778765        1.000000
# EN_SC_EXCHANGE    0.153214  0.145703        0.511154        0.556352
# EN_SC_EXCHANGE.1 -0.153214 -0.145703       -0.511154       -0.556352
# EN_NET_EXPORT     0.043339  0.133070        0.553793        0.531708
# SC_NET_EXPORT    -0.202163 -0.069013       -0.240088       -0.327579
# EN_NET_IMPORT    -0.043339 -0.133070       -0.553793       -0.531708
# SC_NET_IMPORT     0.202163  0.069013        0.240088        0.327579
# EN_GAS           -0.039652 -0.061302        0.214068        0.390719
# SC_GAS            0.026414 -0.021454        0.638804        0.795425
# EN_COAL           0.079258 -0.008463        0.487807        0.505015
# SC_COAL           0.032310  0.043647        0.543219        0.577236
# EN_HYDRO         -0.106444 -0.102365       -0.338429       -0.409388
# SC_HYDRO         -0.140927  0.010246        0.370594        0.641530
# EN_NUCLEAR       -0.206109 -0.012760        0.204025        0.320747
# SC_NUCLEAR       -0.170571  0.008845        0.561216        0.717063
# EN_SOLAR          0.020373 -0.021655       -0.626942       -0.701550
# SC_SOLAR          0.120685 -0.065336       -0.530025       -0.659122
# EN_WINDPOW        0.034753  0.113705        0.491649        0.338430
# SC_WINDPOW        0.058451  0.023082        0.332250        0.274647
# EN_LIGNITE        0.075166 -0.049497        0.407272        0.367228
# EN_RESIDUAL_LOAD -0.029476 -0.104804        0.214672        0.302151
# SC_RESIDUAL_LOAD -0.052963  0.032848        0.725274        0.969865
# EN_RAIN           0.061338  0.067726        0.171177        0.016451
# SC_RAIN           0.023354  0.007206       -0.067915       -0.100909
# EN_WIND           0.291963  0.073382        0.296213        0.041246
# SC_WIND           0.312709  0.062377        0.146887       -0.056124
# EN_TEMP          -0.011145  0.027746        0.083825       -0.030949
# SC_TEMP           0.056008 -0.004038       -0.208647       -0.323231
# GAS_RET           0.026427 -0.045529       -0.081320       -0.116166
# COAL_RET          0.100684 -0.106809        0.109913        0.064006
# CARBON_RET        0.038061 -0.065067        0.079788       -0.037883
#
#                   EN_SC_EXCHANGE  EN_SC_EXCHANGE.1  EN_NET_EXPORT  \
# ID                      0.153214         -0.153214       0.043339
# DAY_ID                  0.145703         -0.145703       0.133070
# EN_CONSUMPTION          0.511154         -0.511154       0.553793
# SC_CONSUMPTION          0.556352         -0.556352       0.531708
# EN_SC_EXCHANGE          1.000000         -1.000000       0.678865
# EN_SC_EXCHANGE.1       -1.000000          1.000000      -0.678865
# EN_NET_EXPORT           0.678865         -0.678865       1.000000
# SC_NET_EXPORT          -0.687954          0.687954      -0.200608
# EN_NET_IMPORT          -0.678865          0.678865      -1.000000
# SC_NET_IMPORT           0.687954         -0.687954       0.200608
# EN_GAS                  0.097358         -0.097358      -0.246837
# SC_GAS                  0.555794         -0.555794       0.351722
# EN_COAL                 0.449172         -0.449172       0.193609
# SC_COAL                 0.410435         -0.410435       0.305766
# EN_HYDRO               -0.341804          0.341804      -0.485155
# SC_HYDRO                0.080895         -0.080895       0.086116
# EN_NUCLEAR             -0.087271          0.087271       0.171273
# SC_NUCLEAR              0.117114         -0.117114       0.381302
# EN_SOLAR               -0.390666          0.390666      -0.503395
# SC_SOLAR               -0.255930          0.255930      -0.473246
# EN_WINDPOW              0.407415         -0.407415       0.776095
# SC_WINDPOW              0.054015         -0.054015       0.419085
# EN_LIGNITE              0.270266         -0.270266       0.125954
# EN_RESIDUAL_LOAD       -0.046386          0.046386      -0.392044
# SC_RESIDUAL_LOAD        0.552565         -0.552565       0.449209
# EN_RAIN                 0.036293         -0.036293       0.146561
# SC_RAIN                -0.090336          0.090336      -0.037966
# EN_WIND                 0.380499         -0.380499       0.371920
# SC_WIND                 0.181837         -0.181837       0.151840
# EN_TEMP                 0.024366         -0.024366       0.140601
# SC_TEMP                -0.128040          0.128040      -0.000743
# GAS_RET                -0.074163          0.074163      -0.091406
# COAL_RET                0.009889         -0.009889      -0.054774
# CARBON_RET             -0.004027          0.004027      -0.103506
#
#                   SC_NET_EXPORT  EN_NET_IMPORT  SC_NET_IMPORT  ...  \
# ID                    -0.202163      -0.043339       0.202163  ...
# DAY_ID                -0.069013      -0.133070       0.069013  ...
# EN_CONSUMPTION        -0.240088      -0.553793       0.240088  ...
# SC_CONSUMPTION        -0.327579      -0.531708       0.327579  ...
# EN_SC_EXCHANGE        -0.687954      -0.678865       0.687954  ...
# EN_SC_EXCHANGE.1       0.687954       0.678865      -0.687954  ...
# EN_NET_EXPORT         -0.200608      -1.000000       0.200608  ...
# SC_NET_EXPORT          1.000000       0.200608      -1.000000  ...
# EN_NET_IMPORT          0.200608       1.000000      -0.200608  ...
# SC_NET_IMPORT         -1.000000      -0.200608       1.000000  ...
# EN_GAS                -0.364297       0.246837       0.364297  ...
# SC_GAS                -0.569253      -0.351722       0.569253  ...
# EN_COAL               -0.402567      -0.193609       0.402567  ...
# SC_COAL               -0.295476      -0.305766       0.295476  ...
# EN_HYDRO               0.164329       0.485155      -0.164329  ...
# SC_HYDRO               0.024529      -0.086116      -0.024529  ...
# EN_NUCLEAR             0.386342      -0.171273      -0.386342  ...
# SC_NUCLEAR             0.353147      -0.381302      -0.353147  ...
# EN_SOLAR               0.132739       0.503395      -0.132739  ...
# SC_SOLAR              -0.007134       0.473246       0.007134  ...
# EN_WINDPOW            -0.022930      -0.776095       0.022930  ...
# SC_WINDPOW             0.152715      -0.419085      -0.152715  ...
# EN_LIGNITE            -0.283271      -0.125954       0.283271  ...
# EN_RESIDUAL_LOAD      -0.153550       0.392044       0.153550  ...
# SC_RESIDUAL_LOAD      -0.358846      -0.449209       0.358846  ...
# EN_RAIN                0.096255      -0.146561      -0.096255  ...
# SC_RAIN                0.081617       0.037966      -0.081617  ...
# EN_WIND               -0.224649      -0.371920       0.224649  ...
# SC_WIND               -0.123470      -0.151840       0.123470  ...
# EN_TEMP                0.045819      -0.140601      -0.045819  ...
# SC_TEMP                0.144058       0.000743      -0.144058  ...
# GAS_RET                0.056055       0.091406      -0.056055  ...
# COAL_RET               0.002949       0.054774      -0.002949  ...
# CARBON_RET            -0.015501       0.103506       0.015501  ...
#
#                   SC_RESIDUAL_LOAD   EN_RAIN   SC_RAIN   EN_WIND   SC_WIND  \
# ID                       -0.052963  0.061338  0.023354  0.291963  0.312709
# DAY_ID                    0.032848  0.067726  0.007206  0.073382  0.062377
# EN_CONSUMPTION            0.725274  0.171177 -0.067915  0.296213  0.146887
# SC_CONSUMPTION            0.969865  0.016451 -0.100909  0.041246 -0.056124
# EN_SC_EXCHANGE            0.552565  0.036293 -0.090336  0.380499  0.181837
# EN_SC_EXCHANGE.1         -0.552565 -0.036293  0.090336 -0.380499 -0.181837
# EN_NET_EXPORT             0.449209  0.146561 -0.037966  0.371920  0.151840
# SC_NET_EXPORT            -0.358846  0.096255  0.081617 -0.224649 -0.123470
# EN_NET_IMPORT            -0.449209 -0.146561  0.037966 -0.371920 -0.151840
# SC_NET_IMPORT             0.358846 -0.096255 -0.081617  0.224649  0.123470
# EN_GAS                    0.471762 -0.190399  0.011065 -0.396176 -0.338047
# SC_GAS                    0.813149 -0.038242 -0.098582 -0.011325 -0.111574
# EN_COAL                   0.564794 -0.016669 -0.062068 -0.053078  0.020045
# SC_COAL                   0.610146 -0.017340 -0.065216  0.100235  0.010959
# EN_HYDRO                 -0.333256 -0.148762 -0.029317 -0.279060 -0.206448
# SC_HYDRO                  0.686245 -0.084312 -0.010910 -0.369123 -0.397107
# EN_NUCLEAR                0.368779  0.028534 -0.009227 -0.457381 -0.417030
# SC_NUCLEAR                0.723764  0.044184 -0.078787 -0.180857 -0.251381
# EN_SOLAR                 -0.646893 -0.381053 -0.077884 -0.086925 -0.041345
# SC_SOLAR                 -0.627348 -0.216367 -0.188991  0.135671  0.126510
# EN_WINDPOW                0.195736  0.319461  0.019513  0.562466  0.313346
# SC_WINDPOW                0.039849  0.288474  0.152222  0.379516  0.527300
# EN_LIGNITE                0.441173 -0.033986 -0.077277 -0.214635 -0.157753
# EN_RESIDUAL_LOAD          0.414602 -0.123039 -0.013201 -0.500767 -0.301282
# SC_RESIDUAL_LOAD          1.000000 -0.042250 -0.124070 -0.078764 -0.212101
# EN_RAIN                  -0.042250  1.000000  0.183724  0.270397  0.264958
# SC_RAIN                  -0.124070  0.183724  1.000000  0.023175  0.122547
# EN_WIND                  -0.078764  0.270397  0.023175  1.000000  0.818551
# SC_WIND                  -0.212101  0.264958  0.122547  0.818551  1.000000
# EN_TEMP                  -0.044589  0.059944  0.173868  0.085468  0.001010
# SC_TEMP                  -0.356317 -0.037959  0.110799  0.033861  0.051860
# GAS_RET                  -0.100611 -0.108329  0.016436 -0.011566  0.016450
# COAL_RET                  0.055317  0.034883 -0.038970  0.101889  0.135542
# CARBON_RET               -0.018877  0.091427  0.062487  0.011422  0.054853
#
#                    EN_TEMP   SC_TEMP   GAS_RET  COAL_RET  CARBON_RET
# ID               -0.011145  0.056008  0.026427  0.100684    0.038061
# DAY_ID            0.027746 -0.004038 -0.045529 -0.106809   -0.065067
# EN_CONSUMPTION    0.083825 -0.208647 -0.081320  0.109913    0.079788
# SC_CONSUMPTION   -0.030949 -0.323231 -0.116166  0.064006   -0.037883
# EN_SC_EXCHANGE    0.024366 -0.128040 -0.074163  0.009889   -0.004027
# EN_SC_EXCHANGE.1 -0.024366  0.128040  0.074163 -0.009889    0.004027
# EN_NET_EXPORT     0.140601 -0.000743 -0.091406 -0.054774   -0.103506
# SC_NET_EXPORT     0.045819  0.144058  0.056055  0.002949   -0.015501
# EN_NET_IMPORT    -0.140601  0.000743  0.091406  0.054774    0.103506
# SC_NET_IMPORT    -0.045819 -0.144058 -0.056055 -0.002949    0.015501
# EN_GAS           -0.082516 -0.197440  0.068922  0.041774    0.104044
# SC_GAS            0.005149 -0.238349 -0.109383  0.048039   -0.003097
# EN_COAL          -0.029059 -0.182988 -0.053156  0.052181    0.081948
# SC_COAL          -0.067801 -0.249983 -0.056748  0.052644    0.028580
# EN_HYDRO         -0.111492 -0.036474  0.043736 -0.020629    0.172163
# SC_HYDRO         -0.018939 -0.248519 -0.027477  0.031791   -0.046919
# EN_NUCLEAR       -0.160384 -0.209581  0.004047 -0.032699    0.081896
# SC_NUCLEAR       -0.000193 -0.229532 -0.057782  0.043939   -0.002375
# EN_SOLAR         -0.000840  0.222943  0.143227 -0.058759   -0.011783
# SC_SOLAR         -0.142375  0.101669  0.072780 -0.034809   -0.010067
# EN_WINDPOW        0.182027  0.029465 -0.115665  0.016802   -0.100213
# SC_WINDPOW        0.090157  0.106688 -0.081586  0.030997   -0.073673
# EN_LIGNITE       -0.061738 -0.171951 -0.070918  0.033214    0.091387
# EN_RESIDUAL_LOAD -0.149610 -0.223187  0.026502  0.054378    0.153486
# SC_RESIDUAL_LOAD -0.044589 -0.356317 -0.100611  0.055317   -0.018877
# EN_RAIN           0.059944 -0.037959 -0.108329  0.034883    0.091427
# SC_RAIN           0.173868  0.110799  0.016436 -0.038970    0.062487
# EN_WIND           0.085468  0.033861 -0.011566  0.101889    0.011422
# SC_WIND           0.001010  0.051860  0.016450  0.135542    0.054853
# EN_TEMP           1.000000  0.633144 -0.024823  0.016831    0.042013
# SC_TEMP           0.633144  1.000000  0.045286 -0.049924   -0.033311
# GAS_RET          -0.024823  0.045286  1.000000  0.166272    0.392741
# COAL_RET          0.016831 -0.049924  0.166272  1.000000    0.261488
# CARBON_RET        0.042013 -0.033311  0.392741  0.261488    1.000000
#
# [34 rows x 34 columns]
# Warning: Total number of columns (34) exceeds max_columns (20) limiting to first (20) columns.
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_99, *['ID'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_100, *['DAY_ID'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_101, *['EN_CONSUMPTION'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_102, *['SC_CONSUMPTION'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_103, *['ID'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_104, *['DAY_ID'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_105, *['EN_CONSUMPTION'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_106, *['SC_CONSUMPTION'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_107, *[[['ID', 'DAY_ID'], ['DAY_ID', 'EN_CONSUMPTION'], ['EN_CONSUMPTION', 'SC_CONSUMPTION'], ['SC_CONSUMPTION', 'EN_SC_EXCHANGE']]], **{})
# chart

# %%
correlations = test_data.corr(method='pearson')
print(correlations['EN_CONSUMPTION'].sort_values(ascending=False).to_string())
# Out:
# EN_CONSUMPTION      1.000000
# SC_CONSUMPTION      0.778765
# SC_RESIDUAL_LOAD    0.725274
# SC_GAS              0.638804
# SC_NUCLEAR          0.561216
# EN_NET_EXPORT       0.553793
# SC_COAL             0.543219
# EN_SC_EXCHANGE      0.511154
# EN_WINDPOW          0.491649
# EN_COAL             0.487807
# EN_LIGNITE          0.407272
# SC_HYDRO            0.370594
# SC_WINDPOW          0.332250
# EN_WIND             0.296213
# SC_NET_IMPORT       0.240088
# EN_RESIDUAL_LOAD    0.214672
# EN_GAS              0.214068
# EN_NUCLEAR          0.204025
# EN_RAIN             0.171177
# SC_WIND             0.146887
# COAL_RET            0.109913
# EN_TEMP             0.083825
# CARBON_RET          0.079788
# ID                  0.054793
# DAY_ID              0.031010
# SC_RAIN            -0.067915
# GAS_RET            -0.081320
# SC_TEMP            -0.208647
# SC_NET_EXPORT      -0.240088
# EN_HYDRO           -0.338429
# EN_SC_EXCHANGE.1   -0.511154
# SC_SOLAR           -0.530025
# EN_NET_IMPORT      -0.553793
# EN_SOLAR           -0.626942
